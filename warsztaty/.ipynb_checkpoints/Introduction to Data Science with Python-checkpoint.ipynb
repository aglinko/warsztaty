# %% [markdown]
# <ol style="font-size:15px">
# <li> Introduction and outline </li>
# <li> Project Jupiter </li>
# <li> What is Data Science? </li>
# <li> Which programming language is the best and why Python? </li>
# <li> Data analysis and visualization with pandas and matplotlib </li>
# <li> What is Machine Learning? </li>
# <li> Tour of ML algorithms </li>
# <li> Using scikit-learn </li>
# </ol>

# %% [markdown]
# # Data Science

# %% [markdown]
# <i>Technology that learns from experience (data) to predict the future behavior of individuals in order to drive better decisions.</i>

# %% [markdown]
# <img src="dscientist.png">

# %% [markdown]
# # In this workshop
# 1. Preprocesing
# 2. Visualization
# 3. Looking for patterns (Machine Learning)

# %% [markdown]
# # Where data comes from?

# %% [markdown]
# <img src="data_gif.gif">

# %% [markdown]
# <p style="font-size:20px"><i>This glut grows by an estimated <b>2.5 quintillion bytes per day</b> (that’s a 1 with 18 zeros after it)</i></p>

# %% [markdown]
# <img src="hilary.png">

# %% [markdown]
# <img src="love.png">

# %% [markdown]
# # Getting data

# %% [markdown]
# ## Text files

# %%
with open('data.csv', 'r') as f:
    for line in f:
        print line

# %%
import csv

with open('data.csv', 'r') as f:
    reader = csv.reader(f, delimiter='\n')
    for row in reader:
        print row

# %%
import pandas as pd

data = pd.read_csv("data.csv")
data.head()

# %%
data['cnt'].head(10)

# %%
data.loc[:5, ['casual', 'registered', 'cnt']]

# %% [markdown]
# ## Scraping the web

# %%
from bs4 import BeautifulSoup
import requests

html = requests.get("http://womenintechnology.pl").text
soup = BeautifulSoup(html, 'html5lib')
    
paragraphs = soup.find_all('p')

print paragraphs[1]

# %% [markdown]
# ## Using APIs : Twitter
# conda install -c pramukta twython=3.2.0

# %% [markdown]
# https://apps.twitter.com/app/13281778

# %%
from twython import Twython

twitter = Twython('hw9DYs3Ur5OieO0rAD62TtRpP', 'HbFbiXFAjVgM2Mx8x8FI3HHXfoL6gW5TPqxKk9n8xWsREatH0p')
for status in twitter.search(q='"data science"')["statuses"]:
    user = status["user"]["screen_name"].encode('utf-8')
    text = status["text"].encode('utf-8')
    print user, ':', text
    print

# %% [markdown]
# # Python

# %% [markdown]
# Python is a general-purpose, versatile and popular programming language. It's <b> great as a first language </b> because it is <b> concise and easy to read </b>and it is also a good language to have in any programmer's stack as <b> it can be used for everything </b> from web development to software development and <b> scientific applications</b>.

# %% [markdown]
# ## What makes it a good choice for Data Science?

# %% [markdown]
# * easy to integrate with web apps and production databases
# * packages: <b> NumPy</b>, <b>pandas</b>, <b> matplotlib</b>, <b> scikit-learn </b>
# * IDE: <b>Spyder</b>, <b>IPython Notebook</b>
# * easy syntax - more play time
# * <i>I'd rather do math in a general purpose language than try to do general purpose programming in a math language</i>
#
# R vs Python war: https://www.datacamp.com/community/tutorials/r-or-python-for-data-analysis#gs.65nSF9w

# %% [markdown]
# # Homework
#
# <img src="bikes.png">

# %% [markdown]
# <b>Bike sharing dataset</b><br>
# http://archive.ics.uci.edu/ml/datasets/Bike+Sharing+Dataset<br>
# https://www.kaggle.com/c/bike-sharing-demand/data<br>

# %% [markdown]
# <i>The data generated by these systems makes them attractive for researchers because the duration of travel, departure location, arrival location, and time elapsed is explicitly recorded. Bike sharing systems therefore function as a sensor network, which can be used for studying mobility in a city. In this competition, participants are asked to combine historical usage patterns with weather data in order to forecast bike rental demand in the Capital Bikeshare program in Washington, D.C.</i>

# %% [markdown]
# Goal: We want to learn to predict <b>bike rental counts (per hour)</b> from information such as day of the week, weather, season, etc. Having good predictions of customer demand allows a business or service to prepare and increase supply as needed.

# %% [markdown]
# <b>Feature columns:</b><br>
# dteday: date <br>
# season: season (1:spring, 2:summer, 3:fall, 4:winter)<br>
# yr: year (0:2011, 1:2012)<br>
# mnth: month (1 to 12)<br>
# hr: hour (0 to 23)<br>
# holiday: whether day is holiday or not<br>
# weekday: day of the week<br>
# workingday: if day is neither weekend nor holiday is 1, otherwise is 0.<br>
# weathersit:<br>
# 1: Clear, Few clouds, Partly cloudy, Partly cloudy<br>
# 2: Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist<br>
# 3: Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds<br>
# 4: Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog<br>
# temp: Normalized temperature in Celsius. The values are derived via (t-t_min)/(t_max-t_min), t_min=-8, t_max=+39 (only in hourly scale)<br>
# atemp: Normalized feeling temperature in Celsius. The values are derived via (t-t_min)/(t_max-t_min), t_min=-16, t_max=+50 (only in hourly scale)<br>
# hum: Normalized humidity. The values are divided to 100 (max)<br>
# windspeed: Normalized wind speed. The values are divided to 67 (max)<br><br>
# <b>Label columns:</b><br>
# casual: count of casual users<br>
# registered: count of registered users<br>
# cnt: count of total rental bikes including both casual and registered<br><br>
# <b>Extraneous columns:</b><br>
# instant: record index

# %% [markdown]
# ### Load and display a sample of data

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
import numpy as np

# %% [markdown]
# task: Display 10 first rows of columns containing weather information

# %%
"We have %d examples." % data["cnt"].count()
# Out:
# 'We have 17379 examples.'

# %%
"Average bike rental count in 2011-2012 was %d." % data["cnt"].mean()
# Out:
# 'Average bike rental count in 2011-2012 was 189.'

# %% [markdown]
# ### Cleaning & Preprocessing

# %% [markdown]
# watch out - dependent variables! Let's drop 'casual' and 'registered' columns

# %%
data = data.drop('casual',1)
data = data.drop('registered', 1)

# %% [markdown]
# watch out - duplicates! Column 'dtedey' is already represented by 'season', 'yr', 'mnth' and 'weekday'

# %%
data = data.drop('dteday', 1)

# %% [markdown]
# missing values?

# %%
data.isnull().values.any()
# Out:
# False

# %% [markdown]
# note - for ML algorithms we often want to standarize the data with a command: ts_stand = (df - df.mean()) / df.std()
# here it's already done for us

# %%
data.dtypes
# Out:
# instant         int64
# season          int64
# yr              int64
# mnth            int64
# hr              int64
# holiday         int64
# weekday         int64
# workingday      int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# cnt             int64
# dtype: object

# %%
data['cnt'].groupby(data['season']).describe()
# Out:
# season
# 1       count    4242.000000
#         mean      111.114569
#         std       119.224010
#         min         1.000000
#         25%        23.000000
#         50%        76.000000
#         75%       158.000000
#         max       801.000000
# 2       count    4409.000000
#         mean      208.344069
#         std       188.362473
#         min         1.000000
#         25%        46.000000
#         50%       165.000000
#         75%       311.000000
#         max       957.000000
# 3       count    4496.000000
#         mean      236.016237
#         std       197.711630
#         min         1.000000
#         25%        68.000000
#         50%       199.000000
#         75%       345.000000
#         max       977.000000
# 4       count    4232.000000
#         mean      198.868856
#         std       182.967972
#         min         1.000000
#         25%        46.000000
#         50%       155.500000
#         75%       295.000000
# ...

# %% [markdown]
# # Visualization

# %%
plt.scatter(data['hr'], data['cnt'])
plt.show()

# %% [markdown]
# task - Plot temp and cnt on one figure

# %%
plt.scatter(data['instant'], data['cnt'],s=0.1, c=data['workingday'], cmap='jet')

# %% [markdown]
# task: Plot mean cnt for every season

# %%
data.plot(subplots=True, figsize=(25, 25))
plt.legend(loc='best')

# %% [markdown]
# task: What are the values on x and y axis? Which plots are useful for understanding the data?

# %% [markdown]
# # Machine Learning

# %% [markdown]
# <i> Field of study that gives computers the ability to learn without being explicitly programmed </i>

# %% [markdown]
# ## Tour of ML algo

# %% [markdown]
# ### Supervised vs Unsupervised

# %% [markdown]
# <img src="supervised.png">
# <img src="unsupervised.png">
# <img src="semi-super.png">

# %% [markdown]
# ### Algorithms

# %% [markdown]
# <img src="regression.png">
# <img src="linear_reg.gif">
# <img src="clustering.png">
# <img src="tree.png">
# <img src="ann.png">
# <img src="deep.png">
# <img src="dimensionality.png">
# <img src="ensemble.png">

# %% [markdown]
# ## Underfitting vs Overfitting

# %%
from sklearn import linear_model as lm
from random import randint
import matplotlib.pyplot as plt
import numpy as np

x = np.array([-3, -2, -1, 0, 1, 2, 3])
y = np.array([p**3 + randint(0, 20) for p in x])
plt.scatter(x, y)
plt.show()

# %%
deg = 10
lr = lm.LinearRegression()
lr.fit(np.vander(x, deg + 1), y)
x_2 = np.linspace(-4, 4, 100)
y_2 = lr.predict(np.vander(x_2, deg + 1))
plt.plot(x_2, y_2, "b", label='degree ' + str(deg))
plt.legend(loc=2)
plt.plot(x, y, 'ok')
plt.ylim(-30,40)
plt.show()

# %% [markdown]
# <img src="sklearn.png">

# %% [markdown]
# ## Scikit-learn example: KMeans

# %%
from sklearn.cluster import KMeans
import numpy as np

x1 = np.random.normal(loc=(-2,-2),scale=1,size=(10,2))
x2 = np.random.normal(loc=(2,2),scale=1,size=(10,2))
X = np.vstack((x1, x2))
plt.scatter(x1[:,0], x1[:,1])
plt.scatter(x2[:,0], x2[:,1])
plt.show()

# %%
kmeans = KMeans(n_clusters=2, random_state=0).fit(X)
y = kmeans.labels_
plt.scatter(X[:,0],X[:,1],c=y)
y2 = kmeans.cluster_centers_
plt.scatter(y2[:,0],y2[:,1],marker='+')
plt.show()
print kmeans.predict([[-3, -3], [4, 4]])
# Out:
# [1 0]

# %% [markdown]
# ## Sciki-learn example: Decision Trees

# %%
from sklearn.datasets import load_iris
from sklearn import tree
import pydotplus

iris = load_iris()
clf = tree.DecisionTreeClassifier()
clf = clf.fit(iris.data, iris.target)

with open("iris.dot", 'w') as f:
     f = tree.export_graphviz(clf, out_file=f)
import os
os.unlink('iris.dot')

from IPython.display import Image  
dot_data = tree.export_graphviz(clf, out_file=None, 
                         feature_names=iris.feature_names,  
                         class_names=iris.target_names,  
                         filled=True, rounded=True,  
                         special_characters=True)  
graph = pydotplus.graph_from_dot_data(dot_data)  
Image(graph.create_png()) 

#source: http://scikit-learn.org/stable/modules/tree.html

# %% [markdown]
# ## ML Pipeline

# %% [markdown]
# task: How to get the testing data?

# %%
from sklearn.model_selection import train_test_split

y = data['cnt']
X = data.drop('cnt',1)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=0)

# %% [markdown]
# ### Linear model

# %%
from sklearn import linear_model
lasso = linear_model.Lasso(alpha = 0.1)
lasso.fit(X_train,y_train).score(X_test,y_test)
# Out:
# 0.39120560574380847

# %% [markdown]
# task: Read about Lasso, try to improve the score by changing alpha and test_size

# %% [markdown]
# ### Make a prediction

# %%
lasso.predict(X_test[:10])
# Out:
# array([  66.45932449,   54.09296539,  333.24325208,  134.1662158 ,
#         366.40847705,  140.22987905,  196.86723643,  381.05663375,
#         257.9149992 ,  151.63643194])

# %% [markdown]
# ### Pipelines

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline

model = Pipeline([('poly', PolynomialFeatures(degree=2)),
                  ('linear', LinearRegression(fit_intercept=False))])

model.fit(X_train,y_train).score(X_test,y_test)
# Out:
# 0.54261704549402068

# %%
model = Pipeline([('poly', PolynomialFeatures(degree=3)),
                  ('lasso', linear_model.Lasso(alpha=0.01))])

model.fit(X_train,y_train).score(X_test,y_test)
# Out:
# /Users/Aga/.local/lib/python2.7/site-packages/sklearn/linear_model/coordinate_descent.py:479: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# 0.60814154942949239

# %% [markdown]
# Task: Why linear models are doing so poorly?

# %% [markdown]
# Task: Find a scikit-learn model which gives the highest score for default parameters

# %% [markdown]
# https://medium.com/rants-on-machine-learning/the-unreasonable-effectiveness-of-random-forests-f33c3ce28883#.pbv59oqpp

# %% [markdown]
# # Homework

# %%
Send your solutions to agnieszka.slowik44@gmail.com

# %% [markdown]
# ## Resources:
# 1. https://blogs.scientificamerican.com/guest-blog/how-hillary-s-campaign-is-almost-certainly-using-big-data/?print=true
# 2. https://practicalanalytics.co/2015/05/29/love-sex-and-predictive-analytics-tinder-match-com-and-okcupid/
# 3. http://www.marketingdistillery.com/2014/11/29/is-data-science-a-buzzword-modern-data-scientist-defined/
# 4. http://machinelearningmastery.com/a-tour-of-machine-learning-algorithms/

# %% [markdown]
# <img src="datascience.jpg">

# %% [markdown]
# <img src="collective.jpg">

# %% [markdown]
# <img src="predictive.jpg">
